# %%
# !pip install -q keras

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Using TensorFlow backend.

# %%
train_images = train_images.reshape(60000, 784)
test_images = test_images.reshape(10000, 784)

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.2579 - acc: 0.9256
# Epoch 2/5
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.1048 - acc: 0.9687
# Epoch 3/5
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.0682 - acc: 0.9797
# Epoch 4/5
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0499 - acc: 0.9849
# Epoch 5/5
# 10752/60000 [====>.........................] - ETA: 4s - loss: 0.0333 - acc: 0.9910
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0368 - acc: 0.9888

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 0s 43us/step

# %%
print('test_acc:', test_acc)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-130caf15b1a6> in <module>()
# ----> 1 print('test_acc:', test_acc)
#
# NameError: name 'test_acc' is not defined

# %% [markdown]
# Tasks:
# 1. Implement early stopping. Create a histogram of accuracy by epoch and check when the model starts overfitting.
# 2. Add dropout.

# %%
network.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
